# %%
import pandas as pd
from matplotlib import pylab as pl
# %matplotlib inline

# %%
pd.read_csv('Task1/Flight.csv').tail(5)
# Out:
#            Date  Commercial Flight 7-Day Moving Avg  \
# 140  2020-06-19                               46274
# 141  2020-06-20                               46730
# 142  2020-06-21                               47056
# 143  2020-06-22                               47348
# 144  2020-06-23                               47638
#
#      Number of Commercial Flight
# 140                        50656
# 141                        42566
# 142                        43208
# 143                        48510
# 144                        49729

# %%
flight = pd.read_csv('Task1/Flight.csv')
flight.shape
# Out:
# (145, 3)

# %%
flight.describe()
# Out:
#        Commercial Flight 7-Day Moving Avg  Number of Commercial Flight
# count                          145.000000                   145.000000
# mean                         59549.186207                 58263.282759
# std                          31780.095619                 31318.680552
# min                          27969.000000                 23926.000000
# 25%                          32543.000000                 32562.000000
# 50%                          42447.000000                 42566.000000
# 75%                         100782.000000                 95989.000000
# max                         108538.000000                112625.000000

# %%
pl.plot(flight['Date'],flight['Commercial Flight 7-Day Moving Avg'])
a = pl.subplot()
#a.hist(flight['Number of Commercial Flight'])

# %% [markdown]
# ## Uber

# %%
pd.read_csv('Task2/Uber.csv').tail(5)
# Out:
#      Pool - Unavailable  UberX    WAV   UberXL   Car Seat   Black   Black SUV  \
# 202               57.05  59.83  59.83    70.97      74.88  101.41      144.91
# 203               42.10  44.08  44.08    53.69      55.22   74.08      105.45
# 204               29.35  31.35  31.35    36.43      42.49   53.73       78.87
# 205               62.31  65.37  65.37    76.51      78.05  105.48      150.59
# 206               44.54  46.67  46.67    54.43      57.81   75.01      106.69
#
#              Start                                             Stop  \
# 202  Grand Central  John F. Kennedy International Airport Queens NY
# 203  Grand Central               Citi Field 41 Seaver Way Queens NY
# 204  Grand Central                   World Trade Center New York NY
# 205  Grand Central  John F. Kennedy International Airport Queens NY
# 206  Grand Central               Citi Field 41 Seaver Way Queens NY
#
#                 Datetime
# 202  2020-06-24 08:00:00
# 203  2020-06-24 08:00:00
# ...

# %%
b = pd.read_csv('Task2/Uber.csv')
b.describe()
# Out:
#        Pool - Unavailable       UberX         WAV      UberXL    Car Seat  \
# count          207.000000  207.000000  207.000000  207.000000  207.000000
# mean            39.010628   42.416329   42.416329   49.756908   56.808889
# std             11.359068   11.107028   11.107028   14.083995   14.679284
# min             20.750000   24.440000   24.440000   27.140000   35.380000
# 25%             26.945000   30.650000   30.650000   35.515000   41.785000
# 50%             41.170000   45.300000   45.300000   52.660000   56.440000
# 75%             47.620000   50.020000   50.020000   61.015000   71.080000
# max             63.190000   66.290000   66.290000   77.430000   85.710000
#
#             Black   Black SUV
# count  207.000000  207.000000
# mean    73.870386  106.164638
# std     22.114167   30.847256
# min     41.930000   62.060000
# 25%     52.610000   77.470000
# 50%     72.750000  103.610000
# 75%     96.580000  138.300000
# max    115.180000  163.800000

# %%
pd.read_csv('Task2/Uber.csv').head(5)
# Out:
#    Pool - Unavailable  UberX    WAV   UberXL   Car Seat   Black   Black SUV  \
# 0               27.89  31.88  31.88    36.61      43.02   53.99       79.33
# 1               49.17  51.52  51.52    62.65      73.33   99.46      142.17
# 2               40.33  44.75  44.75    51.80      55.88   71.66      102.11
# 3               22.91  26.54  26.54    29.46      37.67   44.72       65.79
# 4               55.40  58.08  58.08    69.22      81.64  110.00      156.68
#
#            Start                                             Stop  \
# 0  Grand Central                   World Trade Center New York NY
# 1  Grand Central  John F. Kennedy International Airport Queens NY
# 2  Grand Central               Citi Field 41 Seaver Way Queens NY
# 3  Grand Central                   World Trade Center New York NY
# 4  Grand Central  John F. Kennedy International Airport Queens NY
#
#               Datetime
# 0  2020-06-04 12:00:00
# 1  2020-06-04 12:00:00
# 2  2020-06-04 12:00:00
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 10 columns):
# Pool - Unavailable    207 non-null float64
# UberX                 207 non-null float64
#  WAV                  207 non-null float64
#  UberXL               207 non-null float64
#  Car Seat             207 non-null float64
#  Black                207 non-null float64
#  Black SUV            207 non-null float64
#  Start                207 non-null object
#  Stop                 207 non-null object
#  Datetime             207 non-null object
# dtypes: float64(7), object(3)
# memory usage: 16.2+ KB

# %%
c = pd.read_csv('Task3/Etsy_Mask_sale.csv')
c.tail(3)
# Out:
#     Item_sold       Revenue        Date
# 14     3341.0  37057.466980  2020-06-22
# 15     4906.0  57404.845719  2020-06-23
# 16     3382.0  38821.744075  2020-06-24

# %%
c['price'] = c['Revenue'] / c['Item_sold']

# %%
c[['price']].plot()
pl.tile('Face mask Average Price Time Series',reps=True)
# Out:
# array(['Face mask Average Price Time Series'], dtype='<U35')

# %%
c_daily = pd.read_json('Task')
